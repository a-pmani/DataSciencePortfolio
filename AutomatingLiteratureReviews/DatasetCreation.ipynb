# %% [markdown]
# # Dataset creation

# %% [markdown]
# Project title: Automating literature reviews using recommender systems
#
#
# Authors : Alarmelu PM, Akhila Bolisetty, Andrew Szeto

# %% [markdown]
# The purpose of this file is to create the dataset for our cold start content-based filtering algorithm.
# We take up rows of data as chunks from the arxiv dataset and make a dataset for our own analysis.

# %%
import pandas as pd

# %%
chunk_size=5000
batch_no=1
for chunk in pd.read_csv('cs_DL.tsv', sep='\t',chunksize=chunk_size):
    chunk.to_csv('chunk'+str(batch_no)+'.csv',index=False)
    batch_no+=1

# %%
df1 = pd.read_csv('chunk1.csv')
df1.head()
# Out:
#    Unnamed: 0                                           abstract  \
# 0      465653  The Microsoft TerraServer stores aerial and sa...
# 1      893071  The World Wide Web is fast becoming a source o...
# 2     1110692  The database research community is rightly pro...
# 3       91255  This paper addresses the issue of making legac...
# 4      465232  This paper presents the design and the current...
#
#              acm_class    arxiv_id  \
# 0    H.2.4;H.2.8;H.3.5  cs/9809011
# 1                H.1.1  cs/9809025
# 2  H.0;H.2;H.3;H.4;H.5  cs/9811013
# 3                H.3.7  cs/9811020
# 4                H.3.7  cs/9812009
#
#                                          author_text   categories  \
# 0  Tom Barclay, Robert Eberl, Jim Gray, John Nord...  cs.DB,cs.DL
# 1               Bernardo A. Huberman, Lada A. Adamic  cs.MA,cs.DL
# 2  Phil Bernstein, Michael Brodie, Stefano Ceri, ...  cs.DB,cs.DL
# 3  Elizabeth Anderson, Robert Atkinson, Cynthia C...        cs.DL
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2664 non-null   int64
#  1   abstract         2664 non-null   object
#  2   acm_class        331 non-null    object
#  3   arxiv_id         2664 non-null   object
#  4   author_text      2664 non-null   object
#  5   categories       2664 non-null   object
#  6   comments         1825 non-null   object
#  7   created          2664 non-null   object
#  8   doi              840 non-null    object
#  9   num_authors      2664 non-null   int64
#  10  num_categories   2664 non-null   int64
#  11  primary_cat      2664 non-null   object
#  12  title            2664 non-null   object
#  13  updated          684 non-null    object
#  14  categories_list  2664 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 312.3+ KB

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'abstract', 'acm_class', 'arxiv_id', 'author_text',
#        'categories', 'comments', 'created', 'doi', 'num_authors',
#        'num_categories', 'primary_cat', 'title', 'updated', 'categories_list'],
#       dtype='object')

# %%
chunk_size=5000
batch_no=2
for chunk in pd.read_csv('cs_DB.tsv', sep='\t',chunksize=chunk_size):
    chunk.to_csv('chunk'+str(batch_no)+'.csv',index=False)
    batch_no+=1

# %%
df2 = pd.read_csv('chunk2.csv')
df2.head()
# Out:
#    Unnamed: 0                                           abstract  \
# 0      329549  NTsort is an external sort on WindowsNT 5.0. I...
# 1      704923  Simple economic and performance arguments sugg...
# 2      465653  The Microsoft TerraServer stores aerial and sa...
# 3     1372704  We study a set of linear transformations on th...
# 4      269336  We propose an improvement of the known DFT-bas...
#
#            acm_class    arxiv_id  \
# 0            D.5;H.2  cs/9809004
# 1              H.3.4  cs/9809005
# 2  H.2.4;H.2.8;H.3.5  cs/9809011
# 3              H.2.2  cs/9809023
# 4            H.2;H.3  cs/9809033
#
#                                          author_text   categories  \
# 0              Jim Gray, Joshua Coates, Chris Nyberg  cs.DB,cs.PF
# 1                             Jim Gray, Goetz Graefe        cs.DB
# 2  Tom Barclay, Robert Eberl, Jim Gray, John Nord...  cs.DB,cs.DL
# 3                   Davood Rafiei, Alberto Mendelzon        cs.DB
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002 entries, 0 to 4001
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       4002 non-null   int64
#  1   abstract         4002 non-null   object
#  2   acm_class        675 non-null    object
#  3   arxiv_id         4002 non-null   object
#  4   author_text      4002 non-null   object
#  5   categories       4002 non-null   object
#  6   comments         2443 non-null   object
#  7   created          4002 non-null   object
#  8   doi              549 non-null    object
#  9   num_authors      4002 non-null   int64
#  10  num_categories   4002 non-null   int64
#  11  primary_cat      4002 non-null   object
#  12  title            4002 non-null   object
#  13  updated          1037 non-null   object
#  14  categories_list  4002 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 469.1+ KB

# %%
import os, glob
path = "/Users/ushapraveen/Documents/MSBA/sem_4/BAN_693/SciencePaper_reco/Dataset_creation"

# %%
all_files = glob.glob(os.path.join(path, "chunk*.csv"))

# %%
all_files
# Out:
# ['/Users/ushapraveen/Documents/MSBA/sem_4/BAN_693/SciencePaper_reco/Dataset_creation/chunk2.csv',
#  '/Users/ushapraveen/Documents/MSBA/sem_4/BAN_693/SciencePaper_reco/Dataset_creation/chunk1.csv']

# %%
col_names=['Unnamed: 0', 'abstract', 'acm_class', 'author_text', 'categories',
           'comments', 'created', 'doi', 'num_authors', 'num_categories',
           'primary_cat', 'title', 'updated', 'categories_list']
df_merged = pd.DataFrame(index=range(10), columns=col_names)

# %%
import glob
files = glob.glob("/Users/ushapraveen/Documents/MSBA/sem_4/BAN_693/SciencePaper_reco/Dataset_creation/chunk*.csv")
dfs = [pd.read_csv(f, header=None, sep=",") for f in files]

science_papers = pd.concat(dfs,ignore_index=True)

# %%
science_papers
# Out:
#               0                                                  1   \
# 0     Unnamed: 0                                           abstract
# 1         329549  NTsort is an external sort on WindowsNT 5.0. I...
# 2         704923  Simple economic and performance arguments sugg...
# 3         465653  The Microsoft TerraServer stores aerial and sa...
# 4        1372704  We study a set of linear transformations on th...
# ...          ...                                                ...
# 6663      586717  Objective: Translational science aims at "tran...
# 6664      750271  A Wikipedia book (known as Wikibook) is a coll...
# 6665     1173063  As science advances, the academic community ha...
# 6666      357648  Mechanisms are a fundamental concept in many a...
# 6667     1369244  Alternative metrics (aka altmetrics) are gaini...
#
#                      2           3   \
# 0             acm_class    arxiv_id
# 1               D.5;H.2  cs/9809004
# 2                 H.3.4  cs/9809005
# ...

# %%
science_papers.columns = science_papers.iloc[0]
science_papers = science_papers[1:]

# %%
science_papers
# Out:
# 0    Unnamed: 0                                           abstract  \
# 1        329549  NTsort is an external sort on WindowsNT 5.0. I...
# 2        704923  Simple economic and performance arguments sugg...
# 3        465653  The Microsoft TerraServer stores aerial and sa...
# 4       1372704  We study a set of linear transformations on th...
# 5        269336  We propose an improvement of the known DFT-bas...
# ...         ...                                                ...
# 6663     586717  Objective: Translational science aims at "tran...
# 6664     750271  A Wikipedia book (known as Wikibook) is a coll...
# 6665    1173063  As science advances, the academic community ha...
# 6666     357648  Mechanisms are a fundamental concept in many a...
# 6667    1369244  Alternative metrics (aka altmetrics) are gaini...
#
# 0             acm_class    arxiv_id  \
# 1               D.5;H.2  cs/9809004
# 2                 H.3.4  cs/9809005
# 3     H.2.4;H.2.8;H.3.5  cs/9809011
# ...

# %%
science_papers.to_csv('science_papers.csv') # dataset for the content based filtering
