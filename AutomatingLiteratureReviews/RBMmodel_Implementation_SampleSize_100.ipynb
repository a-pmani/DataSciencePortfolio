# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# WARNING:tensorflow:From /Users/ushapraveen/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#import the dataset with user profiles and ratings
df_in = pd.read_csv('sciencepapers_with_userprofiles.csv')

# %%
df_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2294 entries, 0 to 2293
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user              2294 non-null   int64
#  1   Area of interest  2294 non-null   object
#  2   Input             2294 non-null   object
#  3   title             2294 non-null   object
#  4   rating            2286 non-null   float64
#  5   arxiv_id          2294 non-null   object
#  6   paperId           2294 non-null   object
#  7   created           2294 non-null   object
#  8   categories        2292 non-null   object
#  9   authors           2294 non-null   object
#  10  keywords          2294 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 197.3+ KB

# %%
#fill the missing rating values using the median value 3
df_in.rating = df_in.rating.fillna(3).astype(int)
df_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2294 entries, 0 to 2293
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user              2294 non-null   int64
#  1   Area of interest  2294 non-null   object
#  2   Input             2294 non-null   object
#  3   title             2294 non-null   object
#  4   rating            2294 non-null   int64
#  5   arxiv_id          2294 non-null   object
#  6   paperId           2294 non-null   object
#  7   created           2294 non-null   object
#  8   categories        2292 non-null   object
#  9   authors           2294 non-null   object
#  10  keywords          2294 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 197.3+ KB

# %%
#getting the columns we need in a list 
rating_cols = ['user','paperId','rating'] 
rating =  df_in[rating_cols]
rating
# Out:
#       user    paperId  rating
# 0        1    7051457       5
# 1        1   10050214       1
# 2        1    7051453       3
# 3        1    7043501       2
# 4        1    8092686       3
# ...    ...        ...     ...
# 2289   222   12023461       3
# 2290   222   10074602       3
# 2291   222  180609339       2
# 2292   222    1610065       2
# 2293   222  181110865       2
#
# [2294 rows x 3 columns]

# %%
n_uniq_users = rating['user'].nunique()
n_uniq_papers = rating['paperId'].nunique()
print('number of unique users in the dataset :',n_uniq_users)
print('number of unique science papers in the dataset :',n_uniq_papers)
# Out:
# number of unique users in the dataset : 222
# number of unique science papers in the dataset : 592

# %% [markdown]
# # Data preparation for the RBM implementation

# %% [markdown]
# In order to implement the RBM model, we will need a symmetrical sample size of the papers and the users.
#
# Hence we will come up with something like a inner id implementation - like an internal mapping to identify papers and users.

# %%
#lets us process the paperId column first followed by the users

# %%
#first we will group the dataset based on the paperIds with highest ratings and take the top 100 indexes
paperIndex = rating.groupby("paperId").count().sort_values(by="rating",ascending=False)[0:100].index

#get the paper detaols from ratings dataframe
paperIndex_details = rating[rating.paperId.isin(paperIndex)]
paperIndex_details
# Out:
#       user    paperId  rating
# 4        1    8092686       3
# 5        1   14112855       3
# 6        1  170108029       4
# 10       2    7071304       2
# 14       2  170108029       5
# ...    ...        ...     ...
# 2289   222   12023461       3
# 2290   222   10074602       3
# 2291   222  180609339       2
# 2292   222    1610065       2
# 2293   222  181110865       2
#
# [920 rows x 3 columns]

# %%
#do the same for users but from the papers we selected earlier
userIndex = paperIndex_details.groupby("user").count().sort_values(by="rating",ascending=False).sample(n=100, random_state=2018).index
#get the user details from the rating dataframe
userIndex_details = paperIndex_details[paperIndex_details.user.isin(userIndex)]
userIndex_details
# Out:
#       user    paperId  rating
# 30       4  181006021       4
# 31       4   13075437       5
# 32       4   13054054       4
# 33       4  180904284       4
# 34       4   14015465       2
# ...    ...        ...     ...
# 2239   215   14015465       4
# 2240   215   14080517       4
# 2242   215  181006021       5
# 2243   215  181011832       5
# 2256   217   13120156       4
#
# [539 rows x 3 columns]

# %%
#make up the new inner iids for papers
papers = userIndex_details.paperId.unique()
papersDF = pd.DataFrame(data=papers,columns=['originalPaperId'])
papersDF['paper_iid'] = papersDF.index+1

#make up the new inner iids for users
users = userIndex_details.user.unique()
usersDF = pd.DataFrame(data=users,columns=['originalUserId'])
usersDF['user_iid'] = usersDF.index+1

# %%
#prepare the rbm dataset by merging the datasets we have made thus far.


rbm_dataset = userIndex_details.merge(papersDF,left_on='paperId',right_on='originalPaperId')
rbm_dataset.drop(labels='originalPaperId', axis=1, inplace=True)

rbm_dataset = rbm_dataset.merge(usersDF,left_on='user',right_on='originalUserId')
rbm_dataset.drop(labels='originalUserId', axis=1, inplace=True)

rbm_dataset.head()
# Out:
#    user    paperId  rating  paper_iid  user_iid
# 0     4  181006021       4          1         1
# 1     4   13075437       5          2         1
# 2     4   13054054       4          3         1
# 3     4  180904284       4          4         1
# 4     4   14015465       2          5         1

# %%
#check the users and paper samples now
n_uniq_users = rbm_dataset['user'].nunique()
n_uniq_papers = rbm_dataset['paperId'].nunique()
print('number of unique users in the dataset :',n_uniq_users)
print('number of unique science papers in the dataset :',n_uniq_papers)
# Out:
# number of unique users in the dataset : 100
# number of unique science papers in the dataset : 100

# %% [markdown]
# Now we have a balanced dataset with 100 unique users and 100 unique papers.

# %% [markdown]
# # Building the model and testing the accuracy for 100 samples

# %%
#split the dataset
train, test = train_test_split(rbm_dataset, test_size=0.20, shuffle=True, random_state=2018)
validation, test = train_test_split(test, test_size=0.50, shuffle=True, random_state=2018)

# %%
print('length of training set',len(train))
print('length of test set',len(test))
print('length of validation set',len(validation))
# Out:
# length of training set 431
# length of test set 54
# length of validation set 54

# %%
RBM_train = np.zeros((n_uniq_users, n_uniq_papers))
for row in train.itertuples():
    print(row)
    RBM_train[row[5]-1, row[4]-1] = row[3]
    print('EOR')
# Out:
# Pandas(Index=428, user=70, paperId='1408546', rating=2, paper_iid=78, user_iid=28)
# EOR
# Pandas(Index=503, user=104, paperId='12023461', rating=3, paper_iid=71, user_iid=46)
# EOR
# Pandas(Index=11, user=30, paperId='13075437', rating=5, paper_iid=2, user_iid=14)
# EOR
# Pandas(Index=534, user=217, paperId='13120156', rating=4, paper_iid=81, user_iid=100)
# EOR
# Pandas(Index=435, user=143, paperId='170104182', rating=3, paper_iid=46, user_iid=71)
# EOR
# Pandas(Index=86, user=215, paperId='14015465', rating=2, paper_iid=5, user_iid=99)
# EOR
# Pandas(Index=283, user=213, paperId='160309434', rating=4, paper_iid=27, user_iid=97)
# EOR
# Pandas(Index=132, user=210, paperId='170504928', rating=4, paper_iid=94, user_iid=95)
# EOR
# Pandas(Index=102, user=100, paperId='160605787', rating=3, paper_iid=9, user_iid=43)
# EOR
# Pandas(Index=397, user=39, paperId='12092664', rating=3, paper_iid=64, user_iid=19)
# EOR
# Pandas(Index=284, user=213, paperId='181011049', rating=4, paper_iid=28, user_iid=97)
# EOR
# Pandas(Index=295, user=17, paperId='160309434', rating=4, paper_iid=27, user_iid=8)
# EOR
# Pandas(Index=407, user=147, paperId='150205701', rating=3, paper_iid=34, user_iid=73)
# EOR
# Pandas(Index=48, user=99, paperId='170702047', rating=2, paper_iid=93, user_iid=42)
# EOR
# Pandas(Index=524, user=79, paperId='13120156', rating=4, paper_iid=81, user_iid=31)
# EOR
# Pandas(Index=65, user=137, paperId='14015465', rating=2, paper_iid=5, user_iid=67)
# EOR
# Pandas(Index=223, user=197, paperId='181012125', rating=2, paper_iid=25, user_iid=90)
# EOR
# Pandas(Index=261, user=205, paperId='170700297', rating=1, paper_iid=15, user_iid=94)
# EOR
# Pandas(Index=341, user=96, paperId='170305481', rating=3, paper_iid=49, user_iid=40)
# EOR
# Pandas(Index=73, user=138, paperId='14015465', rating=4, paper_iid=5, user_iid=68)
# EOR
# Pandas(Index=50, user=99, paperId='701156', rating=5, paper_iid=95, user_iid=42)
# EOR
# Pandas(Index=82, user=215, paperId='13075437', rating=5, paper_iid=2, user_iid=99)
# EOR
# Pandas(Index=450, user=109, paperId='11060304', rating=4, paper_iid=56, user_iid=48)
# EOR
# Pandas(Index=481, user=200, paperId='1011081', rating=2, paper_iid=63, user_iid=92)
# EOR
# Pandas(Index=486, user=48, paperId='160104385', rating=5, paper_iid=67, user_iid=21)
# EOR
# Pandas(Index=212, user=176, paperId='180609447', rating=3, paper_iid=21, user_iid=84)
# EOR
# Pandas(Index=15, user=30, paperId='170907493', rating=4, paper_iid=6, user_iid=14)
# EOR
# Pandas(Index=54, user=111, paperId='180904284', rating=4, paper_iid=4, user_iid=49)
# EOR
# Pandas(Index=247, user=91, paperId='12030061', rating=4, paper_iid=16, user_iid=36)
# EOR
# Pandas(Index=249, user=91, paperId='180706996', rating=3, paper_iid=17, user_iid=36)
# EOR
# Pandas(Index=372, user=126, paperId='13081838', rating=3, paper_iid=33, user_iid=57)
# EOR
# Pandas(Index=202, user=89, paperId='180609447', rating=4, paper_iid=21, user_iid=34)
# EOR
# Pandas(Index=258, user=199, paperId='13036609', rating=4, paper_iid=86, user_iid=91)
# EOR
# Pandas(Index=256, user=199, paperId='180701016', rating=3, paper_iid=14, user_iid=91)
# EOR
# Pandas(Index=199, user=69, paperId='170700827', rating=2, paper_iid=30, user_iid=27)
# EOR
# Pandas(Index=12, user=30, paperId='13054054', rating=4, paper_iid=3, user_iid=14)
# EOR
# Pandas(Index=152, user=26, paperId='14112855', rating=2, paper_iid=51, user_iid=12)
# EOR
# Pandas(Index=186, user=8, paperId='171104595', rating=3, paper_iid=12, user_iid=3)
# EOR
# Pandas(Index=169, user=133, paperId='170104182', rating=1, paper_iid=46, user_iid=63)
# EOR
# Pandas(Index=67, user=137, paperId='18110166', rating=2, paper_iid=7, user_iid=67)
# EOR
# Pandas(Index=498, user=104, paperId='9093892', rating=1, paper_iid=68, user_iid=46)
# EOR
# Pandas(Index=389, user=39, paperId='12124565', rating=5, paper_iid=40, user_iid=19)
# EOR
# Pandas(Index=289, user=63, paperId='180609447', rating=4, paper_iid=21, user_iid=24)
# EOR
# Pandas(Index=514, user=52, paperId='181108143', rating=3, paper_iid=75, user_iid=22)
# EOR
# Pandas(Index=139, user=113, paperId='160605787', rating=3, paper_iid=9, user_iid=50)
# EOR
# Pandas(Index=378, user=21, paperId='150205701', rating=3, paper_iid=34, user_iid=11)
# EOR
# Pandas(Index=340, user=96, paperId='180508169', rating=2, paper_iid=47, user_iid=40)
# EOR
# Pandas(Index=69, user=137, paperId='160605787', rating=4, paper_iid=9, user_iid=67)
# EOR
# Pandas(Index=312, user=151, paperId='170700827', rating=2, paper_iid=30, user_iid=75)
# EOR
# Pandas(Index=506, user=104, paperId='181110865', rating=2, paper_iid=74, user_iid=46)
# EOR
# Pandas(Index=366, user=37, paperId='13081838', rating=4, paper_iid=33, user_iid=18)
# EOR
# Pandas(Index=324, user=192, paperId='1408546', rating=2, paper_iid=78, user_iid=88)
# EOR
# Pandas(Index=434, user=131, paperId='160808252', rating=1, paper_iid=90, user_iid=61)
# EOR
# Pandas(Index=474, user=93, paperId='12084166', rating=2, paper_iid=87, user_iid=37)
# EOR
# Pandas(Index=40, user=99, paperId='160605787', rating=4, paper_iid=9, user_iid=42)
# EOR
# Pandas(Index=72, user=138, paperId='13075437', rating=5, paper_iid=2, user_iid=68)
# EOR
# Pandas(Index=184, user=167, paperId='12092664', rating=3, paper_iid=64, user_iid=80)
# EOR
# Pandas(Index=66, user=137, paperId='170907493', rating=4, paper_iid=6, user_iid=67)
# EOR
# Pandas(Index=120, user=118, paperId='14117343', rating=4, paper_iid=83, user_iid=52)
# EOR
# Pandas(Index=322, user=192, paperId='170700827', rating=2, paper_iid=30, user_iid=88)
# EOR
# Pandas(Index=308, user=151, paperId='150201963', rating=3, paper_iid=26, user_iid=75)
# EOR
# Pandas(Index=369, user=37, paperId='170701425', rating=3, paper_iid=36, user_iid=18)
# EOR
# Pandas(Index=233, user=90, paperId='13036609', rating=4, paper_iid=86, user_iid=35)
# EOR
# Pandas(Index=63, user=137, paperId='13054054', rating=4, paper_iid=3, user_iid=67)
# EOR
# Pandas(Index=126, user=210, paperId='13075437', rating=4, paper_iid=2, user_iid=95)
# EOR
# Pandas(Index=167, user=132, paperId='160808252', rating=3, paper_iid=90, user_iid=62)
# EOR
# Pandas(Index=328, user=171, paperId='12110689', rating=2, paper_iid=31, user_iid=81)
# EOR
# Pandas(Index=194, user=16, paperId='180301135', rating=2, paper_iid=24, user_iid=7)
# EOR
# Pandas(Index=265, user=205, paperId='15090091', rating=3, paper_iid=19, user_iid=94)
# EOR
# Pandas(Index=234, user=13, paperId='171206223', rating=5, paper_iid=13, user_iid=5)
# EOR
# Pandas(Index=356, user=18, paperId='180104437', rating=5, paper_iid=35, user_iid=9)
# EOR
# Pandas(Index=307, user=124, paperId='180704639', rating=1, paper_iid=32, user_iid=56)
# EOR
# Pandas(Index=78, user=138, paperId='14080517', rating=4, paper_iid=59, user_iid=68)
# EOR
# Pandas(Index=364, user=19, paperId='150500796', rating=3, paper_iid=37, user_iid=10)
# EOR
# Pandas(Index=64, user=137, paperId='180904284', rating=4, paper_iid=4, user_iid=67)
# EOR
# Pandas(Index=122, user=118, paperId='170504928', rating=4, paper_iid=94, user_iid=52)
# EOR
# Pandas(Index=468, user=134, paperId='13044184', rating=1, paper_iid=61, user_iid=64)
# EOR
# Pandas(Index=538, user=204, paperId='13020337', rating=1, paper_iid=92, user_iid=93)
# EOR
# Pandas(Index=436, user=143, paperId='180508169', rating=1, paper_iid=47, user_iid=71)
# EOR
# Pandas(Index=5, user=4, paperId='170907493', rating=4, paper_iid=6, user_iid=1)
# EOR
# Pandas(Index=441, user=29, paperId='7071548', rating=5, paper_iid=52, user_iid=13)
# EOR
# Pandas(Index=405, user=128, paperId='13126675', rating=3, paper_iid=44, user_iid=59)
# EOR
# Pandas(Index=422, user=146, paperId='13104802', rating=2, paper_iid=62, user_iid=72)
# EOR
# Pandas(Index=520, user=174, paperId='170506218', rating=2, paper_iid=77, user_iid=82)
# EOR
# Pandas(Index=504, user=104, paperId='180609339', rating=2, paper_iid=72, user_iid=46)
# EOR
# Pandas(Index=444, user=29, paperId='170108029', rating=5, paper_iid=55, user_iid=13)
# EOR
# Pandas(Index=236, user=13, paperId='15090091', rating=3, paper_iid=19, user_iid=5)
# EOR
# Pandas(Index=83, user=215, paperId='13075437', rating=5, paper_iid=2, user_iid=99)
# EOR
# Pandas(Index=477, user=119, paperId='1011081', rating=3, paper_iid=63, user_iid=53)
# EOR
# Pandas(Index=130, user=210, paperId='14117343', rating=4, paper_iid=83, user_iid=95)
# EOR
# Pandas(Index=36, user=99, paperId='13075437', rating=5, paper_iid=2, user_iid=42)
# EOR
# Pandas(Index=20, user=31, paperId='181006021', rating=5, paper_iid=1, user_iid=15)
# EOR
# Pandas(Index=417, user=127, paperId='13104802', rating=2, paper_iid=62, user_iid=58)
# EOR
# Pandas(Index=343, user=96, paperId='181108143', rating=4, paper_iid=75, user_iid=40)
# EOR
# Pandas(Index=388, user=39, paperId='180102383', rating=4, paper_iid=39, user_iid=19)
# EOR
# Pandas(Index=252, user=117, paperId='12030061', rating=4, paper_iid=16, user_iid=51)
# EOR
# Pandas(Index=231, user=90, paperId='181012125', rating=2, paper_iid=25, user_iid=35)
# EOR
# Pandas(Index=267, user=15, paperId='181210937', rating=4, paper_iid=20, user_iid=6)
# EOR
# Pandas(Index=31, user=97, paperId='13054054', rating=4, paper_iid=3, user_iid=41)
# EOR
# Pandas(Index=338, user=94, paperId='170901154', rating=2, paper_iid=91, user_iid=38)
# EOR
# Pandas(Index=136, user=189, paperId='160600996', rating=2, paper_iid=8, user_iid=87)
# EOR
# Pandas(Index=70, user=137, paperId='12084175', rating=4, paper_iid=10, user_iid=67)
# EOR
# Pandas(Index=219, user=197, paperId='180609447', rating=4, paper_iid=21, user_iid=90)
# EOR
# Pandas(Index=2, user=4, paperId='13054054', rating=4, paper_iid=3, user_iid=1)
# EOR
# Pandas(Index=354, user=18, paperId='13081838', rating=4, paper_iid=33, user_iid=9)
# EOR
# Pandas(Index=28, user=31, paperId='181011832', rating=5, paper_iid=60, user_iid=15)
# EOR
# Pandas(Index=32, user=97, paperId='180904284', rating=4, paper_iid=4, user_iid=41)
# EOR
# Pandas(Index=51, user=111, paperId='181006021', rating=4, paper_iid=1, user_iid=49)
# EOR
# Pandas(Index=275, user=102, paperId='180704639', rating=1, paper_iid=32, user_iid=44)
# EOR
# Pandas(Index=348, user=214, paperId='180508169', rating=2, paper_iid=47, user_iid=98)
# EOR
# Pandas(Index=24, user=31, paperId='160605787', rating=4, paper_iid=9, user_iid=15)
# EOR
# Pandas(Index=458, user=212, paperId='7071548', rating=5, paper_iid=52, user_iid=96)
# EOR
# Pandas(Index=454, user=136, paperId='7071304', rating=3, paper_iid=54, user_iid=66)
# EOR
# Pandas(Index=151, user=26, paperId='14021258', rating=1, paper_iid=50, user_iid=12)
# EOR
# Pandas(Index=399, user=128, paperId='150205701', rating=3, paper_iid=34, user_iid=59)
# EOR
# Pandas(Index=476, user=93, paperId='180708477', rating=3, paper_iid=89, user_iid=37)
# EOR
# Pandas(Index=279, user=122, paperId='181210937', rating=4, paper_iid=20, user_iid=55)
# EOR
# Pandas(Index=479, user=119, paperId='150101149', rating=2, paper_iid=100, user_iid=53)
# EOR
# Pandas(Index=196, user=69, paperId='18051232', rating=3, paper_iid=11, user_iid=27)
# EOR
# Pandas(Index=131, user=210, paperId='12070139', rating=4, paper_iid=84, user_iid=95)
# EOR
# Pandas(Index=321, user=84, paperId='9091784', rating=5, paper_iid=82, user_iid=32)
# EOR
# Pandas(Index=331, user=171, paperId='170901154', rating=2, paper_iid=91, user_iid=81)
# EOR
# Pandas(Index=103, user=100, paperId='160605787', rating=3, paper_iid=9, user_iid=43)
# EOR
# Pandas(Index=81, user=215, paperId='181006021', rating=5, paper_iid=1, user_iid=99)
# EOR
# Pandas(Index=391, user=39, paperId='160106296', rating=4, paper_iid=42, user_iid=19)
# EOR
# Pandas(Index=416, user=127, paperId='180102383', rating=4, paper_iid=39, user_iid=58)
# EOR
# Pandas(Index=278, user=102, paperId='12070139', rating=3, paper_iid=84, user_iid=44)
# EOR
# Pandas(Index=347, user=214, paperId='180704639', rating=3, paper_iid=32, user_iid=98)
# EOR
# Pandas(Index=19, user=30, paperId='12084175', rating=4, paper_iid=10, user_iid=14)
# EOR
# Pandas(Index=113, user=100, paperId='14126477', rating=5, paper_iid=97, user_iid=43)
# EOR
# Pandas(Index=204, user=150, paperId='171104595', rating=2, paper_iid=12, user_iid=74)
# EOR
# Pandas(Index=396, user=39, paperId='1011081', rating=3, paper_iid=63, user_iid=19)
# EOR
# Pandas(Index=386, user=39, paperId='150205701', rating=3, paper_iid=34, user_iid=19)
# EOR
# Pandas(Index=206, user=150, paperId='180609447', rating=5, paper_iid=21, user_iid=74)
# EOR
# Pandas(Index=334, user=94, paperId='170305481', rating=3, paper_iid=49, user_iid=38)
# EOR
# Pandas(Index=314, user=151, paperId='180704639', rating=1, paper_iid=32, user_iid=75)
# EOR
# Pandas(Index=368, user=37, paperId='180104437', rating=5, paper_iid=35, user_iid=18)
# EOR
# Pandas(Index=133, user=210, paperId='701156', rating=5, paper_iid=95, user_iid=95)
# EOR
# Pandas(Index=197, user=69, paperId='180609447', rating=3, paper_iid=21, user_iid=27)
# EOR
# Pandas(Index=84, user=215, paperId='13054054', rating=4, paper_iid=3, user_iid=99)
# EOR
# Pandas(Index=180, user=140, paperId='160808252', rating=3, paper_iid=90, user_iid=69)
# EOR
# Pandas(Index=10, user=30, paperId='181006021', rating=4, paper_iid=1, user_iid=14)
# EOR
# Pandas(Index=447, user=109, paperId='7071548', rating=5, paper_iid=52, user_iid=48)
# EOR
# Pandas(Index=215, user=176, paperId='12125636', rating=3, paper_iid=76, user_iid=84)
# EOR
# Pandas(Index=483, user=200, paperId='12032574', rating=4, paper_iid=88, user_iid=92)
# EOR
# Pandas(Index=14, user=30, paperId='14015465', rating=2, paper_iid=5, user_iid=14)
# EOR
# Pandas(Index=494, user=48, paperId='181110865', rating=2, paper_iid=74, user_iid=21)
# EOR
# Pandas(Index=424, user=146, paperId='12092664', rating=3, paper_iid=64, user_iid=72)
# EOR
# Pandas(Index=30, user=97, paperId='13075437', rating=5, paper_iid=2, user_iid=41)
# EOR
# Pandas(Index=166, user=132, paperId='181108143', rating=1, paper_iid=75, user_iid=62)
# EOR
# Pandas(Index=423, user=146, paperId='1011081', rating=3, paper_iid=63, user_iid=72)
# EOR
# Pandas(Index=385, user=21, paperId='181111593', rating=1, paper_iid=45, user_iid=11)
# EOR
# Pandas(Index=17, user=30, paperId='160600996', rating=3, paper_iid=8, user_iid=14)
# EOR
# Pandas(Index=35, user=99, paperId='181006021', rating=5, paper_iid=1, user_iid=42)
# EOR
# Pandas(Index=467, user=68, paperId='150900693', rating=2, paper_iid=79, user_iid=26)
# EOR
# Pandas(Index=353, user=214, paperId='170901154', rating=2, paper_iid=91, user_iid=98)
# EOR
# Pandas(Index=93, user=215, paperId='160605787', rating=4, paper_iid=9, user_iid=99)
# EOR
# Pandas(Index=266, user=78, paperId='15090091', rating=3, paper_iid=19, user_iid=30)
# EOR
# Pandas(Index=229, user=90, paperId='180204538', rating=4, paper_iid=23, user_iid=35)
# EOR
# Pandas(Index=90, user=215, paperId='18110166', rating=2, paper_iid=7, user_iid=99)
# EOR
# Pandas(Index=384, user=21, paperId='13126675', rating=3, paper_iid=44, user_iid=11)
# EOR
# Pandas(Index=213, user=176, paperId='180301135', rating=2, paper_iid=24, user_iid=84)
# EOR
# Pandas(Index=157, user=34, paperId='180508169', rating=3, paper_iid=47, user_iid=16)
# EOR
# Pandas(Index=536, user=103, paperId='13081471', rating=3, paper_iid=85, user_iid=45)
# EOR
# Pandas(Index=114, user=100, paperId='1404216', rating=5, paper_iid=98, user_iid=43)
# EOR
# Pandas(Index=533, user=186, paperId='13081471', rating=3, paper_iid=85, user_iid=86)
# EOR
# Pandas(Index=442, user=29, paperId='7071304', rating=2, paper_iid=54, user_iid=13)
# EOR
# Pandas(Index=382, user=21, paperId='160106296', rating=4, paper_iid=42, user_iid=11)
# EOR
# Pandas(Index=529, user=186, paperId='13120156', rating=4, paper_iid=81, user_iid=86)
# EOR
# Pandas(Index=248, user=91, paperId='180706996', rating=4, paper_iid=17, user_iid=36)
# EOR
# Pandas(Index=370, user=37, paperId='150500796', rating=3, paper_iid=37, user_iid=18)
# EOR
# Pandas(Index=200, user=69, paperId='12125636', rating=3, paper_iid=76, user_iid=27)
# EOR
# Pandas(Index=214, user=176, paperId='170700827', rating=2, paper_iid=30, user_iid=84)
# EOR
# Pandas(Index=432, user=131, paperId='170104182', rating=3, paper_iid=46, user_iid=61)
# EOR
# Pandas(Index=220, user=197, paperId='1807031', rating=3, paper_iid=22, user_iid=90)
# EOR
# Pandas(Index=299, user=17, paperId='12110689', rating=3, paper_iid=31, user_iid=8)
# EOR
# Pandas(Index=419, user=127, paperId='12092664', rating=3, paper_iid=64, user_iid=58)
# EOR
# Pandas(Index=158, user=34, paperId='8092686', rating=3, paper_iid=48, user_iid=16)
# EOR
# Pandas(Index=242, user=9, paperId='170700297', rating=1, paper_iid=15, user_iid=4)
# EOR
# Pandas(Index=191, user=16, paperId='180609447', rating=5, paper_iid=21, user_iid=7)
# EOR
# Pandas(Index=448, user=109, paperId='7071304', rating=2, paper_iid=54, user_iid=48)
# EOR
# Pandas(Index=478, user=119, paperId='180708477', rating=1, paper_iid=89, user_iid=53)
# EOR
# Pandas(Index=124, user=118, paperId='180910856', rating=2, paper_iid=96, user_iid=52)
# EOR
# Pandas(Index=518, user=74, paperId='208010', rating=4, paper_iid=80, user_iid=29)
# EOR
# Pandas(Index=373, user=126, paperId='150205701', rating=3, paper_iid=34, user_iid=57)
# EOR
# Pandas(Index=38, user=99, paperId='14015465', rating=4, paper_iid=5, user_iid=42)
# EOR
# Pandas(Index=53, user=111, paperId='13054054', rating=4, paper_iid=3, user_iid=49)
# EOR
# Pandas(Index=179, user=140, paperId='181108143', rating=1, paper_iid=75, user_iid=69)
# EOR
# Pandas(Index=346, user=96, paperId='170901154', rating=2, paper_iid=91, user_iid=40)
# EOR
# Pandas(Index=88, user=215, paperId='170907493', rating=4, paper_iid=6, user_iid=99)
# EOR
# Pandas(Index=29, user=97, paperId='181006021', rating=4, paper_iid=1, user_iid=41)
# EOR
# Pandas(Index=392, user=39, paperId='12074567', rating=2, paper_iid=43, user_iid=19)
# EOR
# Pandas(Index=303, user=124, paperId='181011049', rating=4, paper_iid=28, user_iid=56)
# EOR
# Pandas(Index=56, user=111, paperId='170907493', rating=4, paper_iid=6, user_iid=49)
# EOR
# Pandas(Index=488, user=48, paperId='9093892', rating=1, paper_iid=68, user_iid=21)
# EOR
# Pandas(Index=497, user=104, paperId='160104385', rating=5, paper_iid=67, user_iid=46)
# EOR
# Pandas(Index=7, user=4, paperId='160600996', rating=3, paper_iid=8, user_iid=1)
# EOR
# Pandas(Index=412, user=147, paperId='12074567', rating=2, paper_iid=43, user_iid=73)
# EOR
# Pandas(Index=361, user=19, paperId='150205701', rating=3, paper_iid=34, user_iid=10)
# EOR
# Pandas(Index=34, user=97, paperId='13020337', rating=1, paper_iid=92, user_iid=41)
# EOR
# Pandas(Index=390, user=39, paperId='14067367', rating=2, paper_iid=41, user_iid=19)
# EOR
# Pandas(Index=410, user=147, paperId='14067367', rating=2, paper_iid=41, user_iid=73)
# EOR
# Pandas(Index=21, user=31, paperId='13075437', rating=5, paper_iid=2, user_iid=15)
# EOR
# Pandas(Index=18, user=30, paperId='160605787', rating=4, paper_iid=9, user_iid=14)
# EOR
# Pandas(Index=526, user=79, paperId='14117343', rating=4, paper_iid=83, user_iid=31)
# EOR
# Pandas(Index=85, user=215, paperId='180904284', rating=4, paper_iid=4, user_iid=99)
# EOR
# Pandas(Index=351, user=214, paperId='181108143', rating=4, paper_iid=75, user_iid=98)
# EOR
# Pandas(Index=76, user=138, paperId='12084175', rating=5, paper_iid=10, user_iid=68)
# EOR
# Pandas(Index=495, user=104, paperId='10074602', rating=3, paper_iid=65, user_iid=46)
# EOR
# Pandas(Index=332, user=94, paperId='180704639', rating=3, paper_iid=32, user_iid=38)
# EOR
# Pandas(Index=281, user=213, paperId='181210937', rating=4, paper_iid=20, user_iid=97)
# EOR
# Pandas(Index=172, user=133, paperId='170305481', rating=2, paper_iid=49, user_iid=63)
# EOR
# Pandas(Index=42, user=99, paperId='180701016', rating=3, paper_iid=14, user_iid=42)
# EOR
# Pandas(Index=162, user=34, paperId='7071548', rating=2, paper_iid=52, user_iid=16)
# EOR
# Pandas(Index=98, user=215, paperId='181011832', rating=5, paper_iid=60, user_iid=99)
# EOR
# Pandas(Index=375, user=126, paperId='170701425', rating=4, paper_iid=36, user_iid=57)
# EOR
# Pandas(Index=516, user=67, paperId='170506218', rating=2, paper_iid=77, user_iid=25)
# EOR
# Pandas(Index=363, user=19, paperId='170701425', rating=4, paper_iid=36, user_iid=10)
# EOR
# Pandas(Index=304, user=124, paperId='1401261', rating=3, paper_iid=29, user_iid=56)
# EOR
# Pandas(Index=490, user=48, paperId='10011276', rating=3, paper_iid=70, user_iid=21)
# EOR
# Pandas(Index=535, user=86, paperId='13081471', rating=2, paper_iid=85, user_iid=33)
# EOR
# Pandas(Index=440, user=135, paperId='170108029', rating=4, paper_iid=55, user_iid=65)
# EOR
# Pandas(Index=380, user=21, paperId='12124565', rating=5, paper_iid=40, user_iid=11)
# EOR
# Pandas(Index=253, user=117, paperId='180706996', rating=4, paper_iid=17, user_iid=51)
# EOR
# Pandas(Index=318, user=84, paperId='14112855', rating=4, paper_iid=51, user_iid=32)
# EOR
# Pandas(Index=144, user=113, paperId='1404216', rating=5, paper_iid=98, user_iid=50)
# EOR
# Pandas(Index=1, user=4, paperId='13075437', rating=5, paper_iid=2, user_iid=1)
# EOR
# Pandas(Index=198, user=69, paperId='180301135', rating=2, paper_iid=24, user_iid=27)
# EOR
# Pandas(Index=55, user=111, paperId='14015465', rating=2, paper_iid=5, user_iid=49)
# EOR
# Pandas(Index=271, user=102, paperId='181011049', rating=4, paper_iid=28, user_iid=44)
# EOR
# Pandas(Index=80, user=215, paperId='181006021', rating=4, paper_iid=1, user_iid=99)
# EOR
# Pandas(Index=46, user=99, paperId='14080517', rating=4, paper_iid=59, user_iid=42)
# EOR
# Pandas(Index=137, user=189, paperId='12084175', rating=2, paper_iid=10, user_iid=87)
# EOR
# Pandas(Index=27, user=31, paperId='14080517', rating=4, paper_iid=59, user_iid=15)
# EOR
# Pandas(Index=387, user=39, paperId='180104437', rating=4, paper_iid=35, user_iid=19)
# EOR
# Pandas(Index=62, user=137, paperId='13075437', rating=5, paper_iid=2, user_iid=67)
# EOR
# Pandas(Index=374, user=126, paperId='180104437', rating=5, paper_iid=35, user_iid=57)
# EOR
# Pandas(Index=438, user=135, paperId='8092686', rating=3, paper_iid=48, user_iid=65)
# EOR
# Pandas(Index=427, user=70, paperId='170506218', rating=3, paper_iid=77, user_iid=28)
# EOR
# Pandas(Index=165, user=132, paperId='180508169', rating=3, paper_iid=47, user_iid=62)
# EOR
# Pandas(Index=335, user=94, paperId='9063112', rating=4, paper_iid=66, user_iid=38)
# EOR
# Pandas(Index=143, user=113, paperId='170702047', rating=4, paper_iid=93, user_iid=50)
# EOR
# Pandas(Index=149, user=26, paperId='8092686', rating=3, paper_iid=48, user_iid=12)
# EOR
# Pandas(Index=327, user=192, paperId='208010', rating=2, paper_iid=80, user_iid=88)
# EOR
# Pandas(Index=337, user=94, paperId='160808252', rating=2, paper_iid=90, user_iid=38)
# EOR
# Pandas(Index=160, user=34, paperId='14021258', rating=1, paper_iid=50, user_iid=16)
# EOR
# Pandas(Index=393, user=39, paperId='13126675', rating=3, paper_iid=44, user_iid=19)
# EOR
# Pandas(Index=270, user=102, paperId='160309434', rating=4, paper_iid=27, user_iid=44)
# EOR
# Pandas(Index=451, user=109, paperId='13012236', rating=3, paper_iid=57, user_iid=48)
# EOR
# Pandas(Index=246, user=91, paperId='12030061', rating=4, paper_iid=16, user_iid=36)
# EOR
# Pandas(Index=475, user=93, paperId='12032574', rating=4, paper_iid=88, user_iid=37)
# EOR
# Pandas(Index=175, user=133, paperId='7071548', rating=2, paper_iid=52, user_iid=63)
# EOR
# Pandas(Index=43, user=99, paperId='170700297', rating=1, paper_iid=15, user_iid=42)
# EOR
# Pandas(Index=433, user=131, paperId='180508169', rating=1, paper_iid=47, user_iid=61)
# EOR
# Pandas(Index=26, user=31, paperId='181009378', rating=5, paper_iid=58, user_iid=15)
# EOR
# Pandas(Index=446, user=29, paperId='13012236', rating=3, paper_iid=57, user_iid=13)
# EOR
# Pandas(Index=491, user=48, paperId='12023461', rating=3, paper_iid=71, user_iid=21)
# EOR
# Pandas(Index=208, user=150, paperId='180204538', rating=4, paper_iid=23, user_iid=74)
# EOR
# Pandas(Index=0, user=4, paperId='181006021', rating=4, paper_iid=1, user_iid=1)
# EOR
# Pandas(Index=123, user=118, paperId='701156', rating=5, paper_iid=95, user_iid=52)
# EOR
# Pandas(Index=45, user=99, paperId='181009378', rating=5, paper_iid=58, user_iid=42)
# EOR
# Pandas(Index=47, user=99, paperId='181011832', rating=5, paper_iid=60, user_iid=42)
# EOR
# Pandas(Index=235, user=13, paperId='170701869', rating=4, paper_iid=18, user_iid=5)
# EOR
# Pandas(Index=311, user=151, paperId='1401261', rating=3, paper_iid=29, user_iid=75)
# EOR
# Pandas(Index=505, user=104, paperId='1610065', rating=2, paper_iid=73, user_iid=46)
# EOR
# Pandas(Index=272, user=102, paperId='1401261', rating=3, paper_iid=29, user_iid=44)
# EOR
# Pandas(Index=187, user=8, paperId='171206223', rating=3, paper_iid=13, user_iid=3)
# EOR
# Pandas(Index=297, user=17, paperId='1401261', rating=3, paper_iid=29, user_iid=8)
# EOR
# Pandas(Index=57, user=111, paperId='18110166', rating=2, paper_iid=7, user_iid=49)
# EOR
# Pandas(Index=52, user=111, paperId='13075437', rating=5, paper_iid=2, user_iid=49)
# EOR
# Pandas(Index=528, user=79, paperId='13081471', rating=3, paper_iid=85, user_iid=31)
# EOR
# Pandas(Index=276, user=102, paperId='9091784', rating=5, paper_iid=82, user_iid=44)
# EOR
# Pandas(Index=530, user=186, paperId='9091784', rating=5, paper_iid=82, user_iid=86)
# EOR
# Pandas(Index=170, user=133, paperId='180508169', rating=3, paper_iid=47, user_iid=63)
# EOR
# Pandas(Index=138, user=189, paperId='13104802', rating=3, paper_iid=62, user_iid=87)
# EOR
# Pandas(Index=119, user=118, paperId='13120156', rating=3, paper_iid=81, user_iid=52)
# EOR
# Pandas(Index=413, user=147, paperId='13126675', rating=3, paper_iid=44, user_iid=73)
# EOR
# Pandas(Index=345, user=96, paperId='160808252', rating=2, paper_iid=90, user_iid=40)
# EOR
# Pandas(Index=437, user=143, paperId='160808252', rating=1, paper_iid=90, user_iid=71)
# EOR
# Pandas(Index=381, user=21, paperId='14067367', rating=2, paper_iid=41, user_iid=11)
# EOR
# Pandas(Index=461, user=212, paperId='11060304', rating=4, paper_iid=56, user_iid=96)
# EOR
# Pandas(Index=471, user=175, paperId='1408546', rating=3, paper_iid=78, user_iid=83)
# EOR
# Pandas(Index=352, user=214, paperId='160808252', rating=2, paper_iid=90, user_iid=98)
# EOR
# Pandas(Index=39, user=99, paperId='170907493', rating=4, paper_iid=6, user_iid=42)
# EOR
# Pandas(Index=501, user=104, paperId='13105254', rating=3, paper_iid=69, user_iid=46)
# EOR
# Pandas(Index=268, user=102, paperId='181210937', rating=4, paper_iid=20, user_iid=44)
# EOR
# Pandas(Index=257, user=199, paperId='170700297', rating=1, paper_iid=15, user_iid=91)
# EOR
# Pandas(Index=125, user=118, paperId='14126477', rating=5, paper_iid=97, user_iid=52)
# EOR
# Pandas(Index=531, user=186, paperId='14117343', rating=4, paper_iid=83, user_iid=86)
# EOR
# Pandas(Index=371, user=37, paperId='12092807', rating=5, paper_iid=38, user_iid=18)
# EOR
# Pandas(Index=508, user=106, paperId='160104385', rating=5, paper_iid=67, user_iid=47)
# EOR
# Pandas(Index=225, user=197, paperId='13036609', rating=4, paper_iid=86, user_iid=90)
# EOR
# Pandas(Index=241, user=9, paperId='180701016', rating=3, paper_iid=14, user_iid=4)
# EOR
# Pandas(Index=521, user=181, paperId='170506218', rating=1, paper_iid=77, user_iid=85)
# EOR
# Pandas(Index=425, user=146, paperId='10074602', rating=4, paper_iid=65, user_iid=72)
# EOR
# Pandas(Index=336, user=94, paperId='181108143', rating=4, paper_iid=75, user_iid=38)
# EOR
# Pandas(Index=298, user=17, paperId='170700827', rating=2, paper_iid=30, user_iid=8)
# EOR
# Pandas(Index=239, user=120, paperId='170701869', rating=4, paper_iid=18, user_iid=54)
# EOR
# Pandas(Index=330, user=171, paperId='9063112', rating=2, paper_iid=66, user_iid=81)
# EOR
# Pandas(Index=349, user=214, paperId='170305481', rating=3, paper_iid=49, user_iid=98)
# EOR
# Pandas(Index=464, user=35, paperId='13044184', rating=1, paper_iid=61, user_iid=17)
# EOR
# Pandas(Index=280, user=157, paperId='181210937', rating=4, paper_iid=20, user_iid=76)
# EOR
# Pandas(Index=510, user=106, paperId='9093892', rating=1, paper_iid=68, user_iid=47)
# EOR
# Pandas(Index=421, user=146, paperId='180102383', rating=4, paper_iid=39, user_iid=72)
# EOR
# Pandas(Index=355, user=18, paperId='150205701', rating=4, paper_iid=34, user_iid=9)
# EOR
# Pandas(Index=210, user=150, paperId='181012125', rating=3, paper_iid=25, user_iid=74)
# EOR
# Pandas(Index=320, user=84, paperId='13120156', rating=4, paper_iid=81, user_iid=32)
# EOR
# Pandas(Index=264, user=205, paperId='180706996', rating=4, paper_iid=17, user_iid=94)
# EOR
# Pandas(Index=23, user=31, paperId='170907493', rating=4, paper_iid=6, user_iid=15)
# EOR
# Pandas(Index=168, user=133, paperId='12084175', rating=1, paper_iid=10, user_iid=63)
# EOR
# Pandas(Index=145, user=113, paperId='14017733', rating=3, paper_iid=99, user_iid=50)
# EOR
# Pandas(Index=3, user=4, paperId='180904284', rating=4, paper_iid=4, user_iid=1)
# EOR
# Pandas(Index=269, user=102, paperId='150201963', rating=3, paper_iid=26, user_iid=44)
# EOR
# Pandas(Index=192, user=16, paperId='1807031', rating=3, paper_iid=22, user_iid=7)
# EOR
# Pandas(Index=493, user=48, paperId='1610065', rating=2, paper_iid=73, user_iid=21)
# EOR
# Pandas(Index=146, user=26, paperId='12084175', rating=1, paper_iid=10, user_iid=12)
# EOR
# Pandas(Index=222, user=197, paperId='180301135', rating=3, paper_iid=24, user_iid=90)
# EOR
# Pandas(Index=537, user=193, paperId='13081471', rating=2, paper_iid=85, user_iid=89)
# EOR
# Pandas(Index=129, user=210, paperId='13120156', rating=3, paper_iid=81, user_iid=95)
# EOR
# Pandas(Index=499, user=104, paperId='9093892', rating=1, paper_iid=68, user_iid=46)
# EOR
# Pandas(Index=142, user=113, paperId='12032574', rating=3, paper_iid=88, user_iid=50)
# EOR
# Pandas(Index=101, user=100, paperId='13075437', rating=4, paper_iid=2, user_iid=43)
# EOR
# Pandas(Index=195, user=16, paperId='181012125', rating=3, paper_iid=25, user_iid=7)
# EOR
# Pandas(Index=414, user=147, paperId='181111593', rating=1, paper_iid=45, user_iid=73)
# EOR
# Pandas(Index=240, user=120, paperId='15090091', rating=3, paper_iid=19, user_iid=54)
# EOR
# Pandas(Index=367, user=37, paperId='150205701', rating=4, paper_iid=34, user_iid=18)
# EOR
# Pandas(Index=457, user=136, paperId='13012236', rating=3, paper_iid=57, user_iid=66)
# EOR
# Pandas(Index=59, user=111, paperId='160605787', rating=4, paper_iid=9, user_iid=49)
# EOR
# Pandas(Index=94, user=215, paperId='12084175', rating=4, paper_iid=10, user_iid=99)
# EOR
# Pandas(Index=300, user=17, paperId='180704639', rating=1, paper_iid=32, user_iid=8)
# EOR
# Pandas(Index=189, user=16, paperId='171104595', rating=2, paper_iid=12, user_iid=7)
# EOR
# Pandas(Index=472, user=175, paperId='150900693', rating=2, paper_iid=79, user_iid=83)
# EOR
# Pandas(Index=25, user=31, paperId='12084175', rating=5, paper_iid=10, user_iid=15)
# EOR
# Pandas(Index=116, user=118, paperId='13075437', rating=4, paper_iid=2, user_iid=52)
# EOR
# Pandas(Index=110, user=100, paperId='12032574', rating=3, paper_iid=88, user_iid=43)
# EOR
# Pandas(Index=171, user=133, paperId='8092686', rating=3, paper_iid=48, user_iid=63)
# EOR
# Pandas(Index=302, user=124, paperId='160309434', rating=4, paper_iid=27, user_iid=56)
# EOR
# Pandas(Index=306, user=124, paperId='12110689', rating=3, paper_iid=31, user_iid=56)
# EOR
# Pandas(Index=487, user=48, paperId='9093892', rating=1, paper_iid=68, user_iid=21)
# EOR
# Pandas(Index=509, user=106, paperId='9093892', rating=1, paper_iid=68, user_iid=47)
# EOR
# Pandas(Index=260, user=205, paperId='180701016', rating=3, paper_iid=14, user_iid=94)
# EOR
# Pandas(Index=173, user=133, paperId='14021258', rating=1, paper_iid=50, user_iid=63)
# EOR
# Pandas(Index=174, user=133, paperId='14112855', rating=2, paper_iid=51, user_iid=63)
# EOR
# Pandas(Index=100, user=7, paperId='180904284', rating=2, paper_iid=4, user_iid=2)
# EOR
# Pandas(Index=445, user=29, paperId='11060304', rating=4, paper_iid=56, user_iid=13)
# EOR
# Pandas(Index=326, user=192, paperId='208010', rating=2, paper_iid=80, user_iid=88)
# EOR
# Pandas(Index=183, user=167, paperId='12084175', rating=3, paper_iid=10, user_iid=80)
# EOR
# Pandas(Index=485, user=48, paperId='10074602', rating=3, paper_iid=65, user_iid=21)
# EOR
# Pandas(Index=207, user=150, paperId='1807031', rating=3, paper_iid=22, user_iid=74)
# EOR
# Pandas(Index=238, user=120, paperId='171206223', rating=5, paper_iid=13, user_iid=54)
# EOR
# Pandas(Index=155, user=34, paperId='12084175', rating=1, paper_iid=10, user_iid=16)
# EOR
# Pandas(Index=456, user=136, paperId='11060304', rating=4, paper_iid=56, user_iid=66)
# EOR
# Pandas(Index=243, user=9, paperId='12030061', rating=4, paper_iid=16, user_iid=4)
# EOR
# Pandas(Index=216, user=197, paperId='18051232', rating=4, paper_iid=11, user_iid=90)
# EOR
# Pandas(Index=449, user=109, paperId='170108029', rating=5, paper_iid=55, user_iid=48)
# EOR
# Pandas(Index=317, user=84, paperId='170700827', rating=2, paper_iid=30, user_iid=32)
# EOR
# Pandas(Index=178, user=140, paperId='180508169', rating=3, paper_iid=47, user_iid=69)
# EOR
# Pandas(Index=342, user=96, paperId='9063112', rating=4, paper_iid=66, user_iid=40)
# EOR
# Pandas(Index=532, user=186, paperId='12070139', rating=3, paper_iid=84, user_iid=86)
# EOR
# Pandas(Index=296, user=17, paperId='181011049', rating=4, paper_iid=28, user_iid=8)
# EOR
# Pandas(Index=305, user=124, paperId='170700827', rating=2, paper_iid=30, user_iid=56)
# EOR
# Pandas(Index=359, user=18, paperId='12092807', rating=5, paper_iid=38, user_iid=9)
# EOR
# Pandas(Index=6, user=4, paperId='18110166', rating=2, paper_iid=7, user_iid=1)
# EOR
# Pandas(Index=147, user=26, paperId='170104182', rating=1, paper_iid=46, user_iid=12)
# EOR
# Pandas(Index=232, user=90, paperId='12125636', rating=1, paper_iid=76, user_iid=35)
# EOR
# Pandas(Index=99, user=7, paperId='13075437', rating=2, paper_iid=2, user_iid=2)
# EOR
# Pandas(Index=480, user=119, paperId='150101149', rating=2, paper_iid=100, user_iid=53)
# EOR
# Pandas(Index=460, user=212, paperId='170108029', rating=5, paper_iid=55, user_iid=96)
# EOR
# Pandas(Index=193, user=16, paperId='180204538', rating=4, paper_iid=23, user_iid=7)
# EOR
# Pandas(Index=211, user=176, paperId='18051232', rating=3, paper_iid=11, user_iid=84)
# EOR
# Pandas(Index=4, user=4, paperId='14015465', rating=2, paper_iid=5, user_iid=1)
# EOR
# Pandas(Index=16, user=30, paperId='18110166', rating=2, paper_iid=7, user_iid=14)
# EOR
# Pandas(Index=323, user=192, paperId='170506218', rating=3, paper_iid=77, user_iid=88)
# EOR
# Pandas(Index=290, user=63, paperId='180204538', rating=2, paper_iid=23, user_iid=24)
# EOR
# Pandas(Index=394, user=39, paperId='181111593', rating=1, paper_iid=45, user_iid=19)
# EOR
# Pandas(Index=221, user=197, paperId='180204538', rating=4, paper_iid=23, user_iid=90)
# EOR
# Pandas(Index=443, user=29, paperId='7071304', rating=3, paper_iid=54, user_iid=13)
# EOR
# Pandas(Index=227, user=90, paperId='170700297', rating=1, paper_iid=15, user_iid=35)
# EOR
# Pandas(Index=22, user=31, paperId='14015465', rating=4, paper_iid=5, user_iid=15)
# EOR
# Pandas(Index=484, user=200, paperId='180708477', rating=3, paper_iid=89, user_iid=92)
# EOR
# Pandas(Index=489, user=48, paperId='13105254', rating=3, paper_iid=69, user_iid=21)
# EOR
# Pandas(Index=117, user=118, paperId='14015465', rating=3, paper_iid=5, user_iid=52)
# EOR
# Pandas(Index=49, user=99, paperId='170504928', rating=4, paper_iid=94, user_iid=42)
# EOR
# Pandas(Index=333, user=94, paperId='180508169', rating=2, paper_iid=47, user_iid=38)
# EOR
# Pandas(Index=134, user=210, paperId='180910856', rating=2, paper_iid=96, user_iid=95)
# EOR
# Pandas(Index=492, user=48, paperId='180609339', rating=2, paper_iid=72, user_iid=21)
# EOR
# Pandas(Index=255, user=117, paperId='170702047', rating=2, paper_iid=93, user_iid=51)
# EOR
# Pandas(Index=141, user=113, paperId='12084166', rating=3, paper_iid=87, user_iid=50)
# EOR
# Pandas(Index=71, user=138, paperId='181006021', rating=5, paper_iid=1, user_iid=68)
# EOR
# Pandas(Index=502, user=104, paperId='10011276', rating=3, paper_iid=70, user_iid=46)
# EOR
# Pandas(Index=287, user=213, paperId='12110689', rating=3, paper_iid=31, user_iid=97)
# EOR
# Pandas(Index=237, user=62, paperId='171206223', rating=5, paper_iid=13, user_iid=23)
# EOR
# Pandas(Index=517, user=74, paperId='170506218', rating=1, paper_iid=77, user_iid=29)
# EOR
# Pandas(Index=470, user=175, paperId='13044184', rating=2, paper_iid=61, user_iid=83)
# EOR
# Pandas(Index=74, user=138, paperId='170907493', rating=4, paper_iid=6, user_iid=68)
# EOR
# Pandas(Index=463, user=162, paperId='13012236', rating=3, paper_iid=57, user_iid=78)
# EOR
# Pandas(Index=109, user=100, paperId='12084166', rating=3, paper_iid=87, user_iid=43)
# EOR
# Pandas(Index=97, user=215, paperId='14080517', rating=4, paper_iid=59, user_iid=99)
# EOR
# Pandas(Index=251, user=117, paperId='170700297', rating=1, paper_iid=15, user_iid=51)
# EOR
# Pandas(Index=429, user=70, paperId='150900693', rating=3, paper_iid=79, user_iid=28)
# EOR
# Pandas(Index=154, user=26, paperId='171005693', rating=4, paper_iid=53, user_iid=12)
# EOR
# Pandas(Index=262, user=205, paperId='12030061', rating=4, paper_iid=16, user_iid=94)
# EOR
# Pandas(Index=415, user=130, paperId='12092807', rating=3, paper_iid=38, user_iid=60)
# EOR
# Pandas(Index=453, user=136, paperId='7071304', rating=2, paper_iid=54, user_iid=66)
# EOR
# Pandas(Index=469, user=142, paperId='13044184', rating=1, paper_iid=61, user_iid=70)
# EOR
# Pandas(Index=188, user=16, paperId='18051232', rating=2, paper_iid=11, user_iid=7)
# EOR
# Pandas(Index=360, user=19, paperId='13081838', rating=3, paper_iid=33, user_iid=10)
# EOR
# Pandas(Index=512, user=106, paperId='1610065', rating=2, paper_iid=73, user_iid=47)
# EOR
# Pandas(Index=466, user=68, paperId='1408546', rating=3, paper_iid=78, user_iid=26)
# EOR
# Pandas(Index=77, user=138, paperId='181009378', rating=5, paper_iid=58, user_iid=68)
# EOR
# Pandas(Index=379, user=21, paperId='180104437', rating=4, paper_iid=35, user_iid=11)
# EOR
# Pandas(Index=465, user=68, paperId='13044184', rating=2, paper_iid=61, user_iid=26)
# EOR
# Pandas(Index=500, user=104, paperId='9093892', rating=1, paper_iid=68, user_iid=46)
# EOR
# Pandas(Index=105, user=100, paperId='1011081', rating=3, paper_iid=63, user_iid=43)
# EOR
# Pandas(Index=254, user=117, paperId='15090091', rating=3, paper_iid=19, user_iid=51)
# EOR
# Pandas(Index=455, user=136, paperId='170108029', rating=5, paper_iid=55, user_iid=66)
# EOR
# Pandas(Index=96, user=215, paperId='181009378', rating=5, paper_iid=58, user_iid=99)
# EOR
# Pandas(Index=205, user=150, paperId='171206223', rating=3, paper_iid=13, user_iid=74)
# EOR
# Pandas(Index=294, user=17, paperId='150201963', rating=3, paper_iid=26, user_iid=8)
# EOR
# Pandas(Index=282, user=213, paperId='150201963', rating=3, paper_iid=26, user_iid=97)
# EOR
# Pandas(Index=128, user=210, paperId='160605787', rating=3, paper_iid=9, user_iid=95)
# EOR
# Pandas(Index=209, user=150, paperId='180301135', rating=2, paper_iid=24, user_iid=74)
# EOR
# Pandas(Index=159, user=34, paperId='170305481', rating=2, paper_iid=49, user_iid=16)
# EOR
# Pandas(Index=203, user=150, paperId='18051232', rating=2, paper_iid=11, user_iid=74)
# EOR
# Pandas(Index=431, user=70, paperId='208010', rating=2, paper_iid=80, user_iid=28)
# EOR
# Pandas(Index=75, user=138, paperId='160605787', rating=4, paper_iid=9, user_iid=68)
# EOR
# Pandas(Index=87, user=215, paperId='14015465', rating=4, paper_iid=5, user_iid=99)
# EOR
# Pandas(Index=148, user=26, paperId='180508169', rating=3, paper_iid=47, user_iid=12)
# EOR
# Pandas(Index=156, user=34, paperId='170104182', rating=1, paper_iid=46, user_iid=16)
# EOR
# Pandas(Index=226, user=90, paperId='171104595', rating=4, paper_iid=12, user_iid=35)
# EOR
# Pandas(Index=250, user=117, paperId='180701016', rating=3, paper_iid=14, user_iid=51)
# EOR

# %%
#calculate the sparsity for our 100 sample dataset
sparsity = float(len(RBM_train.nonzero()[0]))
sparsity /= (RBM_train.shape[0] * RBM_train.shape[1])
sparsity *= 100
print('Sparsity: {:4.2f}%'.format(sparsity))
# Out:
# Sparsity: 4.17%

# %% [markdown]
# # Building the RBM class
# The following RBM class is part of the book,
#
# Hands-On Unsupervised Learning Using Python: How to Build Applied Machine learning solutions from unlabeled data.
# Author: Ankur A.Patel.
#
# We have used the code to learn the implementation of RBM  and to test the efficacy of the model on our dataset.
#
# Acknowledgements to the original author.

# %%
class RBM(object):
    
    def __init__(self, input_size, output_size, 
                 learning_rate, epochs, batchsize):
        # Define hyperparameters
        self._input_size = input_size  #input size of the RBM
        self._output_size = output_size #output size of the RBM
        self.learning_rate = learning_rate
        self.epochs = epochs #number of epochs to train for
        self.batchsize = batchsize
        
        # Initialize weights and biases using zero matrices
        self.w = np.zeros([input_size, output_size], dtype=np.float32) 
        self.hb = np.zeros([output_size], dtype=np.float32)
        self.vb = np.zeros([input_size], dtype=np.float32)

        #defining the functions for the RBM class
        
        #prob_h_given is the forward class where 
        #h is the hidden layer
        #v is the visible layer
    def prob_h_given_v(self, visible, w, hb):
        return tf.nn.sigmoid(tf.matmul(visible, w) + hb)

        #backward pass
    def prob_v_given_h(self, hidden, w, vb):
        return tf.nn.sigmoid(tf.matmul(hidden, tf.transpose(w)) + vb)
        
        #sampling function
    def sample_prob(self, probs):
        return tf.nn.relu(tf.sign(probs - tf.random_uniform(tf.shape(probs))))
    
        #We are using Tensorflow to do the training, hence using the 
        #placeholders for allocating the parameters of the RBM
    def train(self, X):
        _w = tf.placeholder(tf.float32, [self._input_size, self._output_size])
        _hb = tf.placeholder(tf.float32, [self._output_size])
        _vb = tf.placeholder(tf.float32, [self._input_size])
        
        prv_w = np.zeros([self._input_size, self._output_size], dtype=np.float32)
        prv_hb = np.zeros([self._output_size], dtype=np.float32)
        prv_vb = np.zeros([self._input_size], dtype=np.float32)
        
        cur_w = np.zeros([self._input_size, self._output_size], dtype=np.float32)
        cur_hb = np.zeros([self._output_size], dtype=np.float32)
        cur_vb = np.zeros([self._input_size], dtype=np.float32)
        
        v0 = tf.placeholder(tf.float32, [None, self._input_size])
        h0 = self.sample_prob(self.prob_h_given_v(v0, _w, _hb))
        v1 = self.sample_prob(self.prob_v_given_h(h0, _w, _vb))
        h1 = self.prob_h_given_v(v1, _w, _hb)
        
        positive_grad = tf.matmul(tf.transpose(v0), h0)
        negative_grad = tf.matmul(tf.transpose(v1), h1)
        
        update_w = _w + self.learning_rate * (positive_grad - negative_grad) / tf.to_float(tf.shape(v0)[0])
        update_vb = _vb +  self.learning_rate * tf.reduce_mean(v0 - v1, 0)
        update_hb = _hb +  self.learning_rate * tf.reduce_mean(h0 - h1, 0)
        
        err = tf.reduce_mean(tf.square(v0 - v1))
        
        error_list = []
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            
            for epoch in range(self.epochs):
                for start, end in zip(range(0, len(X), self.batchsize),range(self.batchsize,len(X), self.batchsize)):
                    batch = X[start:end]
                    cur_w = sess.run(update_w, feed_dict={v0: batch, _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    cur_hb = sess.run(update_hb, feed_dict={v0: batch, _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    cur_vb = sess.run(update_vb, feed_dict={v0: batch, _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    prv_w = cur_w
                    prv_hb = cur_hb
                    prv_vb = cur_vb
                error = sess.run(err, feed_dict={v0: X, _w: cur_w, _vb: cur_vb, _hb: cur_hb})
                print ('Epoch: %d' % epoch,'reconstruction error: %f' % error)
                error_list.append(error)
            self.w = prv_w
            self.hb = prv_hb
            self.vb = prv_vb
            return error_list

    def rbm_output(self, X):
        
        input_X = tf.constant(X)
        _w = tf.constant(self.w)
        _hb = tf.constant(self.hb)
        _vb = tf.constant(self.vb)
        out = tf.nn.sigmoid(tf.matmul(input_X, _w) + _hb)
        hiddenGen = self.sample_prob(self.prob_h_given_v(input_X, _w, _hb))
        visibleGen = self.sample_prob(self.prob_v_given_h(hiddenGen, _w, _vb))
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            return sess.run(out), sess.run(visibleGen), sess.run(hiddenGen)

# %%
#let us start the training cycle
inputX = RBM_train

#converts the input into float values
inputX = inputX.astype(np.float32)

# %%
# Define the parameters of the RBMs we will train
#input_size = 100
#output_size = 100
#learning_rate = 0.3
#epochs = 500
#batchsize = 10

rbm=RBM(100,100,0.3,500,10)

# %%
# Train RBM model
err = rbm.train(inputX)
outputX, reconstructedX, hiddenX = rbm.rbm_output(inputX)
# Out:
# WARNING:tensorflow:From <ipython-input-17-9c392fc5ea13>:56: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Epoch: 0 reconstruction error: 0.434300
# Epoch: 1 reconstruction error: 0.388600
# Epoch: 2 reconstruction error: 0.362700
# Epoch: 3 reconstruction error: 0.346000
# Epoch: 4 reconstruction error: 0.339700
# Epoch: 5 reconstruction error: 0.335300
# Epoch: 6 reconstruction error: 0.340200
# Epoch: 7 reconstruction error: 0.332500
# Epoch: 8 reconstruction error: 0.332200
# Epoch: 9 reconstruction error: 0.332000
# Epoch: 10 reconstruction error: 0.329700
# Epoch: 11 reconstruction error: 0.326300
# Epoch: 12 reconstruction error: 0.326200
# Epoch: 13 reconstruction error: 0.325900
# Epoch: 14 reconstruction error: 0.325700
# Epoch: 15 reconstruction error: 0.324500
# Epoch: 16 reconstruction error: 0.327900
# Epoch: 17 reconstruction error: 0.328800
# Epoch: 18 reconstruction error: 0.323600
# Epoch: 19 reconstruction error: 0.326100
# Epoch: 20 reconstruction error: 0.326100
# Epoch: 21 reconstruction error: 0.323600
# Epoch: 22 reconstruction error: 0.326500
# Epoch: 23 reconstruction error: 0.325800
# Epoch: 24 reconstruction error: 0.324100
# Epoch: 25 reconstruction error: 0.327400
# Epoch: 26 reconstruction error: 0.324800
# Epoch: 27 reconstruction error: 0.326400
# Epoch: 28 reconstruction error: 0.329200
# Epoch: 29 reconstruction error: 0.324900
# Epoch: 30 reconstruction error: 0.326100
# Epoch: 31 reconstruction error: 0.324400
# Epoch: 32 reconstruction error: 0.324700
# Epoch: 33 reconstruction error: 0.324200
# Epoch: 34 reconstruction error: 0.325700
# Epoch: 35 reconstruction error: 0.325000
# Epoch: 36 reconstruction error: 0.325400
# Epoch: 37 reconstruction error: 0.324600
# Epoch: 38 reconstruction error: 0.325600
# Epoch: 39 reconstruction error: 0.326000
# Epoch: 40 reconstruction error: 0.325400
# Epoch: 41 reconstruction error: 0.324700
# Epoch: 42 reconstruction error: 0.324800
# Epoch: 43 reconstruction error: 0.324400
# Epoch: 44 reconstruction error: 0.325000
# Epoch: 45 reconstruction error: 0.323500
# Epoch: 46 reconstruction error: 0.332400
# Epoch: 47 reconstruction error: 0.326000
# Epoch: 48 reconstruction error: 0.324000
# Epoch: 49 reconstruction error: 0.325600
# Epoch: 50 reconstruction error: 0.325800
# Epoch: 51 reconstruction error: 0.324400
# Epoch: 52 reconstruction error: 0.325900
# Epoch: 53 reconstruction error: 0.330600
# Epoch: 54 reconstruction error: 0.325000
# Epoch: 55 reconstruction error: 0.326000
# Epoch: 56 reconstruction error: 0.326700
# Epoch: 57 reconstruction error: 0.323000
# Epoch: 58 reconstruction error: 0.325300
# Epoch: 59 reconstruction error: 0.327500
# Epoch: 60 reconstruction error: 0.324100
# Epoch: 61 reconstruction error: 0.324100
# Epoch: 62 reconstruction error: 0.322300
# Epoch: 63 reconstruction error: 0.325300
# Epoch: 64 reconstruction error: 0.325500
# Epoch: 65 reconstruction error: 0.322900
# Epoch: 66 reconstruction error: 0.328900
# Epoch: 67 reconstruction error: 0.324000
# Epoch: 68 reconstruction error: 0.326700
# Epoch: 69 reconstruction error: 0.324500
# Epoch: 70 reconstruction error: 0.326200
# Epoch: 71 reconstruction error: 0.327500
# Epoch: 72 reconstruction error: 0.327800
# Epoch: 73 reconstruction error: 0.322900
# Epoch: 74 reconstruction error: 0.324100
# Epoch: 75 reconstruction error: 0.324400
# Epoch: 76 reconstruction error: 0.324000
# Epoch: 77 reconstruction error: 0.323600
# Epoch: 78 reconstruction error: 0.327700
# Epoch: 79 reconstruction error: 0.328400
# Epoch: 80 reconstruction error: 0.323300
# Epoch: 81 reconstruction error: 0.327000
# Epoch: 82 reconstruction error: 0.325700
# Epoch: 83 reconstruction error: 0.325200
# Epoch: 84 reconstruction error: 0.326200
# Epoch: 85 reconstruction error: 0.324400
# Epoch: 86 reconstruction error: 0.328600
# Epoch: 87 reconstruction error: 0.325300
# Epoch: 88 reconstruction error: 0.326200
# Epoch: 89 reconstruction error: 0.329000
# Epoch: 90 reconstruction error: 0.325700
# Epoch: 91 reconstruction error: 0.324400
# Epoch: 92 reconstruction error: 0.324700
# Epoch: 93 reconstruction error: 0.326600
# Epoch: 94 reconstruction error: 0.328900
# Epoch: 95 reconstruction error: 0.326500
# Epoch: 96 reconstruction error: 0.326300
# Epoch: 97 reconstruction error: 0.325100
# Epoch: 98 reconstruction error: 0.324500
# Epoch: 99 reconstruction error: 0.326000
# Epoch: 100 reconstruction error: 0.325700
# Epoch: 101 reconstruction error: 0.325800
# Epoch: 102 reconstruction error: 0.326600
# Epoch: 103 reconstruction error: 0.327400
# Epoch: 104 reconstruction error: 0.325100
# Epoch: 105 reconstruction error: 0.326400
# Epoch: 106 reconstruction error: 0.326700
# Epoch: 107 reconstruction error: 0.327100
# Epoch: 108 reconstruction error: 0.326200
# Epoch: 109 reconstruction error: 0.324500
# Epoch: 110 reconstruction error: 0.327000
# Epoch: 111 reconstruction error: 0.325500
# Epoch: 112 reconstruction error: 0.324400
# Epoch: 113 reconstruction error: 0.324500
# Epoch: 114 reconstruction error: 0.326200
# Epoch: 115 reconstruction error: 0.324100
# Epoch: 116 reconstruction error: 0.324900
# Epoch: 117 reconstruction error: 0.327800
# Epoch: 118 reconstruction error: 0.325100
# Epoch: 119 reconstruction error: 0.325000
# Epoch: 120 reconstruction error: 0.324700
# Epoch: 121 reconstruction error: 0.325200
# Epoch: 122 reconstruction error: 0.324900
# Epoch: 123 reconstruction error: 0.325900
# Epoch: 124 reconstruction error: 0.324600
# Epoch: 125 reconstruction error: 0.328900
# Epoch: 126 reconstruction error: 0.327600
# Epoch: 127 reconstruction error: 0.328000
# Epoch: 128 reconstruction error: 0.324100
# Epoch: 129 reconstruction error: 0.327000
# Epoch: 130 reconstruction error: 0.325400
# Epoch: 131 reconstruction error: 0.328200
# Epoch: 132 reconstruction error: 0.325100
# Epoch: 133 reconstruction error: 0.325600
# Epoch: 134 reconstruction error: 0.327400
# Epoch: 135 reconstruction error: 0.323900
# Epoch: 136 reconstruction error: 0.325000
# Epoch: 137 reconstruction error: 0.323800
# Epoch: 138 reconstruction error: 0.325100
# Epoch: 139 reconstruction error: 0.326800
# Epoch: 140 reconstruction error: 0.325400
# Epoch: 141 reconstruction error: 0.326400
# Epoch: 142 reconstruction error: 0.324200
# Epoch: 143 reconstruction error: 0.326000
# Epoch: 144 reconstruction error: 0.325700
# Epoch: 145 reconstruction error: 0.324500
# Epoch: 146 reconstruction error: 0.324700
# Epoch: 147 reconstruction error: 0.321400
# Epoch: 148 reconstruction error: 0.323300
# Epoch: 149 reconstruction error: 0.325800
# Epoch: 150 reconstruction error: 0.325300
# Epoch: 151 reconstruction error: 0.325900
# Epoch: 152 reconstruction error: 0.322500
# Epoch: 153 reconstruction error: 0.325200
# Epoch: 154 reconstruction error: 0.325400
# Epoch: 155 reconstruction error: 0.325000
# Epoch: 156 reconstruction error: 0.327300
# Epoch: 157 reconstruction error: 0.328500
# Epoch: 158 reconstruction error: 0.323100
# Epoch: 159 reconstruction error: 0.325900
# Epoch: 160 reconstruction error: 0.324400
# Epoch: 161 reconstruction error: 0.326800
# Epoch: 162 reconstruction error: 0.326100
# Epoch: 163 reconstruction error: 0.324700
# Epoch: 164 reconstruction error: 0.324300
# Epoch: 165 reconstruction error: 0.323900
# Epoch: 166 reconstruction error: 0.323100
# Epoch: 167 reconstruction error: 0.326400
# Epoch: 168 reconstruction error: 0.325200
# Epoch: 169 reconstruction error: 0.324800
# Epoch: 170 reconstruction error: 0.325600
# Epoch: 171 reconstruction error: 0.323000
# Epoch: 172 reconstruction error: 0.323400
# Epoch: 173 reconstruction error: 0.326200
# Epoch: 174 reconstruction error: 0.324800
# Epoch: 175 reconstruction error: 0.325100
# Epoch: 176 reconstruction error: 0.323300
# Epoch: 177 reconstruction error: 0.326800
# Epoch: 178 reconstruction error: 0.325500
# Epoch: 179 reconstruction error: 0.327900
# Epoch: 180 reconstruction error: 0.325000
# Epoch: 181 reconstruction error: 0.324800
# Epoch: 182 reconstruction error: 0.324500
# Epoch: 183 reconstruction error: 0.325600
# Epoch: 184 reconstruction error: 0.328000
# Epoch: 185 reconstruction error: 0.326900
# Epoch: 186 reconstruction error: 0.327400
# Epoch: 187 reconstruction error: 0.324600
# Epoch: 188 reconstruction error: 0.325900
# Epoch: 189 reconstruction error: 0.325500
# Epoch: 190 reconstruction error: 0.325600
# Epoch: 191 reconstruction error: 0.326700
# Epoch: 192 reconstruction error: 0.325600
# Epoch: 193 reconstruction error: 0.326100
# Epoch: 194 reconstruction error: 0.326900
# Epoch: 195 reconstruction error: 0.325400
# Epoch: 196 reconstruction error: 0.324300
# Epoch: 197 reconstruction error: 0.328600
# Epoch: 198 reconstruction error: 0.325300
# Epoch: 199 reconstruction error: 0.325800
# Epoch: 200 reconstruction error: 0.327100
# Epoch: 201 reconstruction error: 0.325100
# Epoch: 202 reconstruction error: 0.323300
# Epoch: 203 reconstruction error: 0.325600
# Epoch: 204 reconstruction error: 0.323800
# Epoch: 205 reconstruction error: 0.327800
# Epoch: 206 reconstruction error: 0.324300
# Epoch: 207 reconstruction error: 0.326800
# Epoch: 208 reconstruction error: 0.325500
# Epoch: 209 reconstruction error: 0.325200
# Epoch: 210 reconstruction error: 0.322300
# Epoch: 211 reconstruction error: 0.323000
# Epoch: 212 reconstruction error: 0.322900
# Epoch: 213 reconstruction error: 0.326900
# Epoch: 214 reconstruction error: 0.326900
# Epoch: 215 reconstruction error: 0.326100
# Epoch: 216 reconstruction error: 0.326400
# Epoch: 217 reconstruction error: 0.326700
# Epoch: 218 reconstruction error: 0.324700
# Epoch: 219 reconstruction error: 0.322800
# Epoch: 220 reconstruction error: 0.324400
# Epoch: 221 reconstruction error: 0.324500
# Epoch: 222 reconstruction error: 0.324800
# Epoch: 223 reconstruction error: 0.325300
# Epoch: 224 reconstruction error: 0.326100
# Epoch: 225 reconstruction error: 0.325000
# Epoch: 226 reconstruction error: 0.325700
# Epoch: 227 reconstruction error: 0.324200
# Epoch: 228 reconstruction error: 0.326300
# Epoch: 229 reconstruction error: 0.326400
# Epoch: 230 reconstruction error: 0.327300
# Epoch: 231 reconstruction error: 0.324000
# Epoch: 232 reconstruction error: 0.326700
# Epoch: 233 reconstruction error: 0.326000
# Epoch: 234 reconstruction error: 0.324000
# Epoch: 235 reconstruction error: 0.326400
# Epoch: 236 reconstruction error: 0.323500
# Epoch: 237 reconstruction error: 0.326000
# Epoch: 238 reconstruction error: 0.328600
# Epoch: 239 reconstruction error: 0.326100
# Epoch: 240 reconstruction error: 0.324200
# Epoch: 241 reconstruction error: 0.323400
# Epoch: 242 reconstruction error: 0.322700
# Epoch: 243 reconstruction error: 0.323500
# Epoch: 244 reconstruction error: 0.322200
# Epoch: 245 reconstruction error: 0.327800
# Epoch: 246 reconstruction error: 0.323400
# Epoch: 247 reconstruction error: 0.325500
# Epoch: 248 reconstruction error: 0.325400
# Epoch: 249 reconstruction error: 0.327200
# Epoch: 250 reconstruction error: 0.323400
# Epoch: 251 reconstruction error: 0.328400
# Epoch: 252 reconstruction error: 0.326600
# Epoch: 253 reconstruction error: 0.324200
# Epoch: 254 reconstruction error: 0.325700
# Epoch: 255 reconstruction error: 0.328400
# Epoch: 256 reconstruction error: 0.325600
# Epoch: 257 reconstruction error: 0.326900
# Epoch: 258 reconstruction error: 0.328900
# Epoch: 259 reconstruction error: 0.327000
# Epoch: 260 reconstruction error: 0.326900
# Epoch: 261 reconstruction error: 0.325900
# Epoch: 262 reconstruction error: 0.324900
# Epoch: 263 reconstruction error: 0.326000
# Epoch: 264 reconstruction error: 0.327700
# Epoch: 265 reconstruction error: 0.328100
# Epoch: 266 reconstruction error: 0.326100
# Epoch: 267 reconstruction error: 0.327200
# Epoch: 268 reconstruction error: 0.329200
# Epoch: 269 reconstruction error: 0.323200
# Epoch: 270 reconstruction error: 0.325500
# Epoch: 271 reconstruction error: 0.323900
# Epoch: 272 reconstruction error: 0.326000
# Epoch: 273 reconstruction error: 0.328900
# Epoch: 274 reconstruction error: 0.329300
# Epoch: 275 reconstruction error: 0.328900
# Epoch: 276 reconstruction error: 0.326600
# Epoch: 277 reconstruction error: 0.327000
# Epoch: 278 reconstruction error: 0.329500
# Epoch: 279 reconstruction error: 0.326300
# Epoch: 280 reconstruction error: 0.326800
# Epoch: 281 reconstruction error: 0.326500
# Epoch: 282 reconstruction error: 0.326800
# Epoch: 283 reconstruction error: 0.328600
# Epoch: 284 reconstruction error: 0.325000
# Epoch: 285 reconstruction error: 0.327600
# Epoch: 286 reconstruction error: 0.326700
# Epoch: 287 reconstruction error: 0.325100
# Epoch: 288 reconstruction error: 0.327000
# Epoch: 289 reconstruction error: 0.328800
# Epoch: 290 reconstruction error: 0.327200
# Epoch: 291 reconstruction error: 0.326400
# Epoch: 292 reconstruction error: 0.326400
# Epoch: 293 reconstruction error: 0.327800
# Epoch: 294 reconstruction error: 0.326500
# Epoch: 295 reconstruction error: 0.323600
# Epoch: 296 reconstruction error: 0.326600
# Epoch: 297 reconstruction error: 0.327100
# Epoch: 298 reconstruction error: 0.324700
# Epoch: 299 reconstruction error: 0.326000
# Epoch: 300 reconstruction error: 0.324600
# Epoch: 301 reconstruction error: 0.322400
# Epoch: 302 reconstruction error: 0.322400
# Epoch: 303 reconstruction error: 0.328200
# Epoch: 304 reconstruction error: 0.327700
# Epoch: 305 reconstruction error: 0.322900
# Epoch: 306 reconstruction error: 0.325300
# Epoch: 307 reconstruction error: 0.323200
# Epoch: 308 reconstruction error: 0.323700
# Epoch: 309 reconstruction error: 0.325400
# Epoch: 310 reconstruction error: 0.323400
# Epoch: 311 reconstruction error: 0.325000
# Epoch: 312 reconstruction error: 0.329200
# Epoch: 313 reconstruction error: 0.324500
# Epoch: 314 reconstruction error: 0.324400
# Epoch: 315 reconstruction error: 0.322500
# Epoch: 316 reconstruction error: 0.323600
# Epoch: 317 reconstruction error: 0.329400
# Epoch: 318 reconstruction error: 0.323500
# Epoch: 319 reconstruction error: 0.325500
# Epoch: 320 reconstruction error: 0.326100
# Epoch: 321 reconstruction error: 0.326900
# Epoch: 322 reconstruction error: 0.327000
# Epoch: 323 reconstruction error: 0.325100
# Epoch: 324 reconstruction error: 0.327100
# Epoch: 325 reconstruction error: 0.324400
# Epoch: 326 reconstruction error: 0.322700
# Epoch: 327 reconstruction error: 0.325400
# Epoch: 328 reconstruction error: 0.327400
# Epoch: 329 reconstruction error: 0.323400
# Epoch: 330 reconstruction error: 0.327800
# Epoch: 331 reconstruction error: 0.328500
# Epoch: 332 reconstruction error: 0.326100
# Epoch: 333 reconstruction error: 0.325600
# Epoch: 334 reconstruction error: 0.324400
# Epoch: 335 reconstruction error: 0.325500
# Epoch: 336 reconstruction error: 0.322000
# Epoch: 337 reconstruction error: 0.324200
# Epoch: 338 reconstruction error: 0.325700
# Epoch: 339 reconstruction error: 0.324900
# Epoch: 340 reconstruction error: 0.325700
# Epoch: 341 reconstruction error: 0.325500
# Epoch: 342 reconstruction error: 0.326800
# Epoch: 343 reconstruction error: 0.326100
# Epoch: 344 reconstruction error: 0.325300
# Epoch: 345 reconstruction error: 0.325100
# Epoch: 346 reconstruction error: 0.325500
# Epoch: 347 reconstruction error: 0.326300
# Epoch: 348 reconstruction error: 0.327000
# Epoch: 349 reconstruction error: 0.325600
# Epoch: 350 reconstruction error: 0.325800
# Epoch: 351 reconstruction error: 0.325800
# Epoch: 352 reconstruction error: 0.325600
# Epoch: 353 reconstruction error: 0.323800
# Epoch: 354 reconstruction error: 0.324300
# Epoch: 355 reconstruction error: 0.326600
# Epoch: 356 reconstruction error: 0.325400
# Epoch: 357 reconstruction error: 0.325500
# Epoch: 358 reconstruction error: 0.323700
# Epoch: 359 reconstruction error: 0.326500
# Epoch: 360 reconstruction error: 0.325600
# Epoch: 361 reconstruction error: 0.323400
# Epoch: 362 reconstruction error: 0.323400
# Epoch: 363 reconstruction error: 0.326300
# Epoch: 364 reconstruction error: 0.327100
# Epoch: 365 reconstruction error: 0.325900
# Epoch: 366 reconstruction error: 0.326600
# Epoch: 367 reconstruction error: 0.323700
# Epoch: 368 reconstruction error: 0.326100
# Epoch: 369 reconstruction error: 0.326600
# Epoch: 370 reconstruction error: 0.327500
# Epoch: 371 reconstruction error: 0.327200
# Epoch: 372 reconstruction error: 0.325200
# Epoch: 373 reconstruction error: 0.327200
# Epoch: 374 reconstruction error: 0.327500
# Epoch: 375 reconstruction error: 0.325600
# Epoch: 376 reconstruction error: 0.326300
# Epoch: 377 reconstruction error: 0.326900
# Epoch: 378 reconstruction error: 0.324700
# Epoch: 379 reconstruction error: 0.325200
# Epoch: 380 reconstruction error: 0.324200
# Epoch: 381 reconstruction error: 0.326100
# Epoch: 382 reconstruction error: 0.325700
# Epoch: 383 reconstruction error: 0.325900
# Epoch: 384 reconstruction error: 0.327100
# Epoch: 385 reconstruction error: 0.325700
# Epoch: 386 reconstruction error: 0.326100
# Epoch: 387 reconstruction error: 0.324200
# Epoch: 388 reconstruction error: 0.324500
# Epoch: 389 reconstruction error: 0.325900
# Epoch: 390 reconstruction error: 0.326100
# Epoch: 391 reconstruction error: 0.323900
# Epoch: 392 reconstruction error: 0.325700
# Epoch: 393 reconstruction error: 0.325000
# Epoch: 394 reconstruction error: 0.323500
# Epoch: 395 reconstruction error: 0.328400
# Epoch: 396 reconstruction error: 0.327600
# Epoch: 397 reconstruction error: 0.325300
# Epoch: 398 reconstruction error: 0.325000
# Epoch: 399 reconstruction error: 0.324100
# Epoch: 400 reconstruction error: 0.327900
# Epoch: 401 reconstruction error: 0.326100
# Epoch: 402 reconstruction error: 0.323100
# Epoch: 403 reconstruction error: 0.327700
# Epoch: 404 reconstruction error: 0.327000
# Epoch: 405 reconstruction error: 0.326200
# Epoch: 406 reconstruction error: 0.324800
# Epoch: 407 reconstruction error: 0.324800
# Epoch: 408 reconstruction error: 0.328300
# Epoch: 409 reconstruction error: 0.326700
# Epoch: 410 reconstruction error: 0.325700
# Epoch: 411 reconstruction error: 0.325900
# Epoch: 412 reconstruction error: 0.327300
# Epoch: 413 reconstruction error: 0.326900
# Epoch: 414 reconstruction error: 0.325500
# Epoch: 415 reconstruction error: 0.321000
# Epoch: 416 reconstruction error: 0.324700
# Epoch: 417 reconstruction error: 0.326600
# Epoch: 418 reconstruction error: 0.325400
# Epoch: 419 reconstruction error: 0.325100
# Epoch: 420 reconstruction error: 0.327900
# Epoch: 421 reconstruction error: 0.328800
# Epoch: 422 reconstruction error: 0.328500
# Epoch: 423 reconstruction error: 0.326200
# Epoch: 424 reconstruction error: 0.329400
# Epoch: 425 reconstruction error: 0.324900
# Epoch: 426 reconstruction error: 0.324400
# Epoch: 427 reconstruction error: 0.327000
# Epoch: 428 reconstruction error: 0.326200
# Epoch: 429 reconstruction error: 0.323800
# Epoch: 430 reconstruction error: 0.325900
# Epoch: 431 reconstruction error: 0.325700
# Epoch: 432 reconstruction error: 0.326800
# Epoch: 433 reconstruction error: 0.327700
# Epoch: 434 reconstruction error: 0.325000
# Epoch: 435 reconstruction error: 0.322400
# Epoch: 436 reconstruction error: 0.323600
# Epoch: 437 reconstruction error: 0.323900
# Epoch: 438 reconstruction error: 0.325500
# Epoch: 439 reconstruction error: 0.326800
# Epoch: 440 reconstruction error: 0.327400
# Epoch: 441 reconstruction error: 0.324800
# Epoch: 442 reconstruction error: 0.325100
# Epoch: 443 reconstruction error: 0.327000
# Epoch: 444 reconstruction error: 0.325300
# Epoch: 445 reconstruction error: 0.327400
# Epoch: 446 reconstruction error: 0.327600
# Epoch: 447 reconstruction error: 0.326200
# Epoch: 448 reconstruction error: 0.327300
# Epoch: 449 reconstruction error: 0.326600
# Epoch: 450 reconstruction error: 0.327100
# Epoch: 451 reconstruction error: 0.324200
# Epoch: 452 reconstruction error: 0.327400
# Epoch: 453 reconstruction error: 0.325600
# Epoch: 454 reconstruction error: 0.324800
# Epoch: 455 reconstruction error: 0.325400
# Epoch: 456 reconstruction error: 0.327500
# Epoch: 457 reconstruction error: 0.325900
# Epoch: 458 reconstruction error: 0.326200
# Epoch: 459 reconstruction error: 0.327100
# Epoch: 460 reconstruction error: 0.326700
# Epoch: 461 reconstruction error: 0.326800
# Epoch: 462 reconstruction error: 0.324500
# Epoch: 463 reconstruction error: 0.327100
# Epoch: 464 reconstruction error: 0.323600
# Epoch: 465 reconstruction error: 0.327000
# Epoch: 466 reconstruction error: 0.327700
# Epoch: 467 reconstruction error: 0.326100
# Epoch: 468 reconstruction error: 0.324800
# Epoch: 469 reconstruction error: 0.326200
# Epoch: 470 reconstruction error: 0.325400
# Epoch: 471 reconstruction error: 0.327100
# Epoch: 472 reconstruction error: 0.325600
# Epoch: 473 reconstruction error: 0.326000
# Epoch: 474 reconstruction error: 0.325100
# Epoch: 475 reconstruction error: 0.324600
# Epoch: 476 reconstruction error: 0.327300
# Epoch: 477 reconstruction error: 0.324900
# Epoch: 478 reconstruction error: 0.326100
# Epoch: 479 reconstruction error: 0.326500
# Epoch: 480 reconstruction error: 0.323700
# Epoch: 481 reconstruction error: 0.324700
# Epoch: 482 reconstruction error: 0.322900
# Epoch: 483 reconstruction error: 0.326500
# Epoch: 484 reconstruction error: 0.322400
# Epoch: 485 reconstruction error: 0.325300
# Epoch: 486 reconstruction error: 0.327200
# Epoch: 487 reconstruction error: 0.327000
# Epoch: 488 reconstruction error: 0.324600
# Epoch: 489 reconstruction error: 0.328700
# Epoch: 490 reconstruction error: 0.326700
# Epoch: 491 reconstruction error: 0.326100
# Epoch: 492 reconstruction error: 0.327000
# Epoch: 493 reconstruction error: 0.325500
# Epoch: 494 reconstruction error: 0.325600
# Epoch: 495 reconstruction error: 0.325200
# Epoch: 496 reconstruction error: 0.325000
# Epoch: 497 reconstruction error: 0.324100
# Epoch: 498 reconstruction error: 0.325300
# Epoch: 499 reconstruction error: 0.326400

# %%
# Plot reconstruction errors
pd.Series(err).plot(logy=False)
plt.xlabel("Epoch")
plt.ylabel("Reconstruction Error")
# Out:
# Text(0, 0.5, 'Reconstruction Error')

# %%
#create the validation set
ratings_validation = np.zeros((n_uniq_users, n_uniq_papers))
for row in validation.itertuples():
    ratings_validation[row[5]-1, row[4]-1] = row[3]

# Predict ratings for validation set
inputValidation = ratings_validation
inputValidation = inputValidation.astype(np.float32)
finalOutput_validation, reconstructedOutput_validation, _ = rbm.rbm_output(inputValidation)

# %%
# Calculate MSE on validation set
predictionsArray = reconstructedOutput_validation
pred_validation = predictionsArray[ratings_validation.nonzero()].flatten()
actual_validation = ratings_validation[ratings_validation.nonzero()].flatten()
rbm_prediction = mean_squared_error(pred_validation, actual_validation)
print('Mean squared error using RBM prediction:', rbm_prediction)
# Out:
# Mean squared error using RBM prediction: 6.811320754716981
